# %% [markdown]
# ## health_care_facilities.json

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the "health_care_facilities.json" file into a GeoDataFrame using GeoPandas.

# %%
import geopandas as gpd
import pandas as pd
import plotly.express as px
import json
from IPython.display import display

try:
    # Load the GeoJSON file
    gdf = gpd.read_file("/content/health_care_facilities.json")

    # Ensure the CRS is set correctly
    if gdf.crs is None:
        gdf.set_crs(epsg=4326, inplace=True)
    else:
        gdf = gdf.to_crs(epsg=4326)

    # Extract latitude and longitude
    gdf["longitude"] = gdf.geometry.x
    gdf["latitude"] = gdf.geometry.y

    # Display sample data
    display(gdf.head())
except Exception as e:
    print(f"An error occurred: {e}")
    gdf = None
# Out:
#    OBJECTID           TYPE  FLU_CASES                ADDRESS       CITY  \
# 0         1  Nursing homes         50          506 s jackson  Ritzville
# 1         2  Nursing homes         39  495 north 13th street    Othello
# 2         3  Nursing homes         90           1242 11th st  Clarkston
# 3         4  Nursing homes        104      44 goethals drive   Richland
# 4         5  Nursing homes        136   1508 west 7th avenue  Kennewick
#
#      ZIP                                        NAME                        x  \
# 0  99169               Life care center of ritzville  118° 22' 38.81477376" W
# 1  99344           Avalon care center - othello, llc  119° 09' 22.35944555" W
# 2  99403  Prestige care & rehabilitation - clarkston  117° 03' 07.61724119" W
# 3  99352                Life care center of richland  119° 16' 53.98656280" W
# 4  99336               Life care center of kennewick  119° 08' 21.45593089" W
#
#                         y                     geometry   longitude   latitude
# 0  47° 07' 17.98509752" N  POINT (-118.37745 47.12166) -118.377449  47.121663
# 1  46° 49' 51.91884130" N  POINT (-119.15621 46.83109) -119.156211  46.831089
# 2  46° 24' 23.24267987" N  POINT (-117.05212 46.40646) -117.052116  46.406456
# 3  46° 15' 41.92346282" N  POINT (-119.28166 46.26165) -119.281663  46.261645
# 4  46° 12' 08.00065524" N  POINT (-119.13929 46.20222) -119.139293  46.202222

# %% [markdown]
# ## Data exploration

# %%
# Print the shape of the GeoDataFrame
print("Shape of the GeoDataFrame:", gdf.shape)

# Print the data types of each column
print("\nData types of each column:")
print(gdf.dtypes)

# Calculate and print descriptive statistics for relevant numerical columns
print("\nDescriptive statistics for numerical columns:")
numerical_cols = ['FLU_CASES', 'ZIP', 'x', 'y']  # Specify numerical columns
display(gdf[numerical_cols].describe())

# Print the names of columns relevant for creating maps
print("\nColumns relevant for mapping:")
relevant_cols = ['geometry', 'TYPE', 'FLU_CASES', 'CITY', 'ZIP'] # Example relevant columns
print(relevant_cols)
# Out:
# Shape of the GeoDataFrame: (2726, 12)
#
# Data types of each column:
# OBJECTID        int32
# TYPE           object
# FLU_CASES       int16
# ADDRESS        object
# CITY           object
# ZIP            object
# NAME           object
# x              object
# y              object
# geometry     geometry
# longitude     float64
# latitude      float64
# dtype: object
#
# Descriptive statistics for numerical columns:
#          FLU_CASES
# count  2726.000000
# mean    189.169112
# std     143.436122
# min       0.000000
# 25%      70.000000
# 50%     148.500000
# 75%     286.000000
# max     552.000000
# Columns relevant for mapping:
# ['geometry', 'TYPE', 'FLU_CASES', 'CITY', 'ZIP']

# %% [markdown]
# ## Data wrangling
#
# ### Subtask:
#  Handle missing values in the 'TYPE' column.

# %%
# Identify and count missing values in the 'TYPE' column
missing_type_count_before = gdf['TYPE'].isnull().sum()
print(f"Number of missing values in 'TYPE' before handling: {missing_type_count_before}")
# Out:
# Number of missing values in 'TYPE' before handling: 0

# %% [markdown]
# ## Data visualization

# %%
import plotly.express as px

# Ensure gdf is valid before plotting
if gdf is not None and "longitude" in gdf.columns and "latitude" in gdf.columns:
    fig = px.scatter_mapbox(gdf,
                            lat="latitude",
                            lon="longitude",
                            color="TYPE",
                            hover_name="NAME",
                            hover_data=["ADDRESS", "CITY", "FLU_CASES"],
                            zoom=4,
                            height=600,
                            title="Healthcare Facilities in Washington",
                            mapbox_style="carto-positron")

    # Customize the map layout
    fig.update_layout(
        title_font_size=20,
        title_x=0.5,
        margin={"r": 0, "t": 50, "l": 0, "b": 0},
        font=dict(size=12),
        mapbox=dict(
            style="carto-positron",
            center=dict(lat=47.0, lon=-120.5),
            zoom=5.5,
        ),
    )

    fig.show()
else:
    print("Error: GeoDataFrame is empty or missing coordinate columns.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="08d52997-eed4-4ace-9837-85fd7854d868" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08d52997-eed4-4ace-9837-85fd7854d868")) {                    Plotly.newPlot(                        "08d52997-eed4-4ace-9837-85fd7854d868",                        [{"customdata":[["506 s jackson","Ritzville",50],["495 north 13th street","Othello",39],["1242 11th st","Clarkston",90],["44 goethals drive","Richland",104],["1508 west 7th avenue","Kennewick",136],["625 okanogan avenue","Wenatchee",100],["817 pioneer avenue","Cashmere",65],["650 west hemlock st","Sequim",100],["740 ne dallas st","Camas",83],["200 nat washington way","Ephrata",50],["135 south 336th street","Federal way",120],["9201 2nd ave n.w.","Seattle",6],["1201 s miller st","Wenatchee",22],["2702 south ely","Kennewick",53],["1745 pike ave","Richland",71],["5220 ne hazel dell avenue","Vancouver",89],["8507 ne 8th way","Vancouver",92],["2811 ne 139th st","Vancouver",120],["726 north markeson","Chelan",55],["1015 north garrison road","Vancouver",104],["2004 n 22nd ave","Pasco",108],["17127 - 15th avenue ne","Seattle",112],["1031 sw 130th street","Burien",140],["9107 fortuna drive","Mercer island",43],["1116 e lauridsen blvd","Port angeles",101],["510 north parkway","Battle ground",83],["127 second avenue sw","Soap lake",42],["22410 benson road se","Kent",91],["26511 ne virginia street","Duvall",6],["13333 greenwood avenue n","Seattle",119],["1000 fifth avenue south","Sequim",125],["1500 - 3rd avenue","Longview",140],["311 northeast 3rd street","Coupeville",112],["820 nw 95th","Seattle",142],["10901  176th circle northeast","Redmond",61],["6720 e green lake way n","Seattle",44],["530 bogachiel way","Forks",20],["917 - 7th avenue","Longview",74],["800 n medcalf","Montesano",94],["5027 ne 188th","Seattle",6],["26509 ne virginia","Duvall",6],["13023 greenwood avenue n","Seattle",211],["801 se park crest avenue","Vancouver",88],["910 - 16th avenue","Longview",50],["817 east plum street","Moses lake",74],["12461 ne 173rd place","Woodinville",6],["19301 kings garden dr n","Seattle",168],["805 front street south","Issaquah",140],["400 east 33rd street","Vancouver",98],["1012 s third st","Dayton",34],["920 anderson drive","Aberdeen",105],["100 timber ridge way nw","Issaquah",36],["7500 seward park ave so","Seattle",205],["491 s. 338th","Federal way",70],["310 fourth street","Woodland",62],["3035 cherry street","Hoquiam",109],["11 west aloha st","Seattle",50],["4700 phinney avenue no","Seattle",116],["32300 first avenue south","Federal way",147],["10101 ne 120th","Kirkland",190],["128 beacon hill drive","Longview",67],["1100 east nelson rd","Moses lake",111],["2720 east madison","Seattle",35],["502 - 29th street se","Auburn",100],["15230 - 15th ne","Shoreline",92],["4416 south brandon street","Seattle",100],["609 highline drive","East wenatchee",92],["751 kearney st","Port townsend",94],["17235 126th place ne","Woodinville",6],["2323 jensen street","Enumclaw",92],["23620 marine view drive s","Des moines",96],["2611 south dearborn","Seattle",165],["15230 15th ne   d","Seattle",188],["16357 aurora avenue north","Seattle",90],["116 fairview avenue n","Seattle",22],["2717 dexter ave n","Seattle",120],["2818 ne 145th st","Seattle",114],["2031 pottery avenue","Port orchard",125],["12509 greenwood ave n","Seattle",74],["6935 fauntleroy way sw","Seattle",8],["1703 california avenue sw","Seattle",137],["1040 s henderson street","Seattle",100],["2821 south walden street","Seattle",165],["560 lebo boulevard","Bremerton",102],["7125 fauntleroy way sw","Seattle",20],["219 cedar avenue south","North bend",64],["80 sw second street","Renton",99],["24423 - 100th avenue se","Kent",8],["19160 front st ...

# %%
import plotly.express as px

# Ensure gdf is valid before plotting
if gdf is not None and "longitude" in gdf.columns and "latitude" in gdf.columns:
    fig = px.density_mapbox(gdf, lat="latitude", lon="longitude", z="FLU_CASES", radius=10,
                            center=dict(lat=47.0, lon=-120.5), zoom=5,
                            mapbox_style="carto-positron", color_continuous_scale="Viridis")

    # Customize the map layout
    fig.update_layout(
        title="Density of Healthcare Facilities by Flu Cases",
        title_x=0.5,
        title_font_size=20,
        margin={"r": 0, "t": 50, "l": 0, "b": 0},
        font=dict(size=12),
        mapbox=dict(
            style="carto-positron",
            center=dict(lat=47.0, lon=-120.5),
            zoom=5.5,
        ),
    )

    fig.show()
else:
    print("Error: GeoDataFrame is empty or missing coordinate columns.")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="044fb90f-c8bb-4e1f-aef3-859e9b33e34c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("044fb90f-c8bb-4e1f-aef3-859e9b33e34c")) {                    Plotly.newPlot(                        "044fb90f-c8bb-4e1f-aef3-859e9b33e34c",                        [{"coloraxis":"coloraxis","hovertemplate":"FLU_CASES=%{z}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":